# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Group by model and evaluator_name, compute mean of 'score'
grouped = df.groupby(['model', 'evaluator_name'])['score'].mean().reset_index()
grouped = grouped.rename(columns={'score': 'avg_score'})

# Create a combined label column for x-axis
grouped['model_evaluator'] = grouped['model'] + ' | ' + grouped['evaluator_name']

# Plot using the new single-column label
fig, ax = plt.subplots(figsize=(8, 4))
grouped.plot(
    x='model_evaluator',   # now a single string column
    y='avg_score',
    kind='bar',
    ax=ax,
    legend=False
)

plt.title('Average Score by Model and Evaluator')
plt.xlabel('Model | Evaluator')
plt.ylabel('Average Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_882873/4186043804.py:22: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
